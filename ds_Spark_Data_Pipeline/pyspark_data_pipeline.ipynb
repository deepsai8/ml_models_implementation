# %% [markdown]
# # Project Group 15

# %% [markdown]
# ## Summary
# - Group 15 (Aydin Schwartz, Deepak Singh, Tianrui Hu, Vichitra Kumar)
#
# - Data : NY times API Data (https://developer.nytimes.com/docs/archive-product/1/overview)
#
# - Cluster Setting : Multi Node, No Isolation Shared, Runtime : 11.0, Worker/Driver type : e2-highmem-2 (Min workers : 1, Max workers : 2 with autoscaling)
#
# - To improve efficiency, configure to have spark.executor.memory and spark.driver.memory being 4g and .cache() intermediate rdd which being used often.
#
# - Objectives : Using New York Times News Data from 1991 to 2021 from various locations, topics and organizations, see the search trends and plot using line/scatter/bubble plots.
#
# > 1) Visualize trends of overall news articles by locations/topics/organizations using line and/or scatter plots
#
# > 2) Visualize keywords / sections most talked about in the news articles in past 30 years

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import pyspark

from datetime import datetime as dt

# %%
sc._conf.getAll()
# Out:
# Out[2]: [('spark.databricks.preemption.enabled', 'true'),
#  ('spark.databricks.clusterUsageTags.clusterId', '1213-212447-k68mp9tw'),
#  ('spark.sql.hive.metastore.jars', '/databricks/databricks-hive/*'),
#  ('spark.driver.tempDirectory', '/local_disk0/tmp'),
#  ('spark.databricks.clusterUsageTags.onInstancePool', 'false'),
#  ('spark.sql.warehouse.dir', 'dbfs:/user/hive/warehouse'),
#  ('spark.databricks.managedCatalog.clientClassName',
#   'com.databricks.managedcatalog.ManagedCatalogClientImpl'),
#  ('spark.hadoop.fs.gs.impl',
#   'shaded.databricks.com.google.cloud.hadoop.fs.gcs.GoogleHadoopFileSystem'),
#  ('spark.databricks.clusterUsageTags.clusterTargetWorkers', '1'),
#  ('spark.hadoop.fs.fcfs-s3.impl.disable.cache', 'true'),
#  ('spark.hadoop.fs.s3a.retry.limit', '20'),
#  ('spark.sql.streaming.checkpointFileManagerClass',
#   'com.databricks.spark.sql.streaming.DatabricksCheckpointFileManager'),
#  ('spark.databricks.service.dbutils.repl.backend',
#   'com.databricks.dbconnect.ReplDBUtils'),
#  ('spark.hadoop.databricks.s3.verifyBucketExists.enabled', 'false'),
#  ('spark.streaming.driver.writeAheadLog.allowBatching', 'true'),
#  ('spark.databricks.clusterSource', 'UI'),
#  ('spark.databricks.clusterUsageTags.dataPlaneRegion', 'us-west1'),
#  ('spark.hadoop.hive.server2.transport.mode', 'http'),
#  ('spark.databricks.acl.dfAclsEnabled', 'false'),
#  ('spark.hadoop.fs.cpfs-adl.impl.disable.cache', 'true'),
#  ('spark.hadoop.fs.mcfs-s3.impl',
#   'com.databricks.sql.acl.fs.ManagedCatalogFileSystem'),
#  ('spark.eventLog.enabled', 'false'),
#  ('spark.ui.reverseProxy', 'true'),
#  ('spark.hadoop.hive.hmshandler.retry.interval', '2000'),
#  ('spark.executor.tempDirectory', '/local_disk0/tmp'),
#  ('spark.hadoop.fs.azure.authorization.caching.enable', 'false'),
#  ('spark.databricks.clusterUsageTags.dbrClusterDataplaneRegion', ''),
#  ('spark.hadoop.fs.fcfs-abfss.impl',
#   'com.databricks.sql.acl.fs.FixedCredentialsFileSystem'),
#  ('spark.hadoop.mapred.output.committer.class',
#   'com.databricks.backend.daemon.data.client.DirectOutputCommitter'),
#  ('spark.hadoop.hive.server2.thrift.http.port', '10000'),
#  ('spark.hadoop.mapreduce.fileoutputcommitter.algorithm.version', '2'),
#  ('spark.ui.port', '41616'),
#  ('spark.sql.allowMultipleContexts', 'false'),
#  ('spark.databricks.eventLog.enabled', 'true'),
#  ('spark.r.sql.derby.temp.dir', '/tmp/Rtmpsi2Jy0'),
#  ('spark.home', '/databricks/spark'),
#  ('spark.databricks.cloudProvider', 'GCP'),
#  ('spark.hadoop.hive.server2.idle.operation.timeout', '7200000'),
#  ('spark.task.reaper.enabled', 'true'),
#  ('spark.databricks.clusterUsageTags.isNephos', 'false'),
#  ('spark.storage.memoryFraction', '0.5'),
#  ('spark.master', 'spark://driver-proxy:7077'),
#  ('spark.databricks.sql.configMapperClass',
#   'com.databricks.dbsql.config.SqlConfigMapperBridge'),
#  ('spark.driver.maxResultSize', '4g'),
#  ('spark.hadoop.fs.fcfs-s3.impl',
#   'com.databricks.sql.acl.fs.FixedCredentialsFileSystem'),
#  ('spark.databricks.delta.multiClusterWrites.enabled', 'true'),
#  ('spark.worker.cleanup.enabled', 'false'),
#  ('spark.sql.legacy.createHiveTableByDefault', 'false'),
#  ('spark.databricks.clusterUsageTags.clusterOwnerOrgId', '4285859980626871'),
#  ('spark.hadoop.fs.fcfs-s3a.impl.disable.cache', 'true'),
#  ('spark.hadoop.fs.s3a.attempts.maximum', '10'),
#  ('spark.databricks.clusterUsageTags.clusterNodeType', 'e2-highmem-2'),
#  ('spark.hadoop.fs.azure.user.agent.prefix', ''),
#  ('spark.hadoop.fs.fcfs-s3n.impl',
#   'com.databricks.sql.acl.fs.FixedCredentialsFileSystem'),
#  ('spark.hadoop.fs.s3a.retry.throttle.interval', '500ms'),
#  ('spark.hadoop.fs.wasb.impl.disable.cache', 'true'),
#  ('spark.databricks.wsfsPublicPreview', 'true'),
#  ('spark.cleaner.referenceTracking.blocking', 'false'),
#  ('spark.databricks.clusterUsageTags.clusterState', 'Pending'),
#  ('spark.databricks.tahoe.logStore.azure.class',
#   'com.databricks.tahoe.store.AzureLogStore'),
#  ('spark.hadoop.fs.azure.skip.metrics', 'true'),
#  ('spark.hadoop.fs.s3.impl',
#   'shaded.databricks.org.apache.hadoop.fs.s3a.S3AFileSystem'),
#  ('spark.hadoop.hive.hmshandler.retry.attempts', '10'),
#  ('spark.scheduler.mode', 'FAIR'),
#  ('spark.sql.sources.default', 'delta'),
#  ('spark.hadoop.fs.mcfs-gs.impl',
#   'com.databricks.sql.acl.fs.ManagedCatalogFileSystem'),
#  ('spark.hadoop.fs.cpfs-s3n.impl',
#   'com.databricks.sql.acl.fs.CredentialPassthroughFileSystem'),
#  ('spark.hadoop.fs.cpfs-adl.impl',
#   'com.databricks.sql.acl.fs.CredentialPassthroughFileSystem'),
#  ('spark.memory.offHeap.enabled', 'false'),
#  ('spark.hadoop.fs.fcfs-s3n.impl.disable.cache', 'true'),
#  ('spark.hadoop.fs.cpfs-abfss.impl',
#   'com.databricks.sql.acl.fs.CredentialPassthroughFileSystem'),
#  ('spark.databricks.passthrough.oauth.refresher.impl',
#   'com.databricks.backend.daemon.driver.credentials.OAuthTokenRefresherClient'),
#  ('spark.sql.hive.metastore.sharedPrefixes',
#   'org.mariadb.jdbc,com.mysql.jdbc,org.postgresql,com.microsoft.sqlserver,microsoft.sql.DateTimeOffset,microsoft.sql.Types,com.databricks,com.codahale,com.fasterxml.jackson,shaded.databricks'),
#  ('spark.databricks.io.directoryCommit.enableLogicalDelete', 'false'),
#  ('spark.task.reaper.killTimeout', '60s'),
#  ('spark.databricks.managedCatalog.adls.gen2.tokenProviderClassName',
#   'com.databricks.backend.daemon.driver.credentials.ManagedCatalogADLSTokenProvider'),
#  ('spark.hadoop.parquet.block.size.row.check.min', '10'),
#  ('spark.hadoop.hive.server2.use.SSL', 'true'),
#  ('spark.hadoop.fs.mcfs-s3a.impl',
#   'com.databricks.sql.acl.fs.ManagedCatalogFileSystem'),
#  ('spark.hadoop.databricks.dbfs.client.version', 'v2'),
#  ('spark.hadoop.hive.server2.keystore.path',
#   '/databricks/keys/jetty-ssl-driver-keystore.jks'),
#  ('spark.hadoop.fs.elfs.impl.disable.cache', 'true'),
#  ('spark.databricks.credential.redactor',
#   'com.databricks.logging.secrets.CredentialRedactorProxyImpl'),
#  ('spark.databricks.clusterUsageTags.workerEnvironmentId',
#   'workerenv-4285859980626871-2192fbcf-7067-4a0b-a529-f13645141655'),
#  ('spark.databricks.acl.provider',
#   'com.databricks.sql.acl.ReflectionBackedAclProvider'),
#  ('spark.extraListeners',
#   'com.databricks.backend.daemon.driver.DBCEventLoggingListener'),
#  ('spark.databricks.clusterUsageTags.clusterType', 'ondemand'),
#  ('spark.hadoop.spark.databricks.io.parquet.verifyChecksumOnWrite.enabled',
#   'false'),
#  ('spark.sql.parquet.cacheMetadata', 'true'),
#  ('spark.hadoop.parquet.abfs.readahead.optimization.enabled', 'true'),
#  ('spark.hadoop.fs.adl.impl', 'com.databricks.adl.AdlFileSystem'),
#  ('spark.hadoop.fs.dbfs.impl',
#   'com.databricks.backend.daemon.data.client.DBFS'),
#  ('spark.hadoop.fs.cpfs-abfss.impl.disable.cache', 'true'),
#  ('spark.databricks.clusterUsageTags.cloudProvider', 'GCP'),
#  ('spark.databricks.tahoe.logStore.class',
#   'com.databricks.tahoe.store.DelegatingLogStore'),
#  ('spark.hadoop.spark.hadoop.aws.glue.cache.db.ttl-mins', '30'),
#  ('spark.hadoop.spark.hadoop.aws.glue.cache.table.ttl-mins', '30'),
#  ('libraryDownload.sleepIntervalSeconds', '5'),
#  ('spark.sql.hive.convertMetastoreParquet', 'true'),
#  ('spark.databricks.service.dbutils.server.backend',
#   'com.databricks.dbconnect.SparkServerDBUtils'),
#  ('spark.executor.id', 'driver'),
#  ('spark.memory.offHeap.size', '0'),
#  ('spark.repl.class.uri', 'spark://driver-proxy:36703/classes'),
#  ('spark.databricks.managedCatalog.s3a.tokenProviderClassName',
#   'com.databricks.backend.daemon.driver.credentials.ManagedCatalogS3TokenProvider'),
#  ('spark.databricks.repl.enableClassFileCleanup', 'true'),
#  ('spark.hadoop.fs.s3a.multipart.size', '10485760'),
#  ('spark.metrics.conf', '/databricks/spark/conf/metrics.properties'),
#  ('spark.executor.extraJavaOptions',
#   '-XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djava.io.tmpdir=/local_disk0/tmp -XX:ReservedCodeCacheSize=512m -XX:+UseCodeCacheFlushing -Djava.security.properties=/databricks/spark/dbconf/java/extra.security -XX:-UseContainerSupport -XX:+PrintFlagsFinal -XX:+PrintGCDateStamps -XX:+PrintGCDetails -verbose:gc -Xss4m -Djava.library.path=/usr/java/packages/lib/amd64:/usr/lib64:/lib64:/lib:/usr/lib:/usr/lib/x86_64-linux-gnu/jni:/lib/x86_64-linux-gnu:/usr/lib/x86_64-linux-gnu:/usr/lib/jni -Djavax.xml.datatype.DatatypeFactory=com.sun.org.apache.xerces.internal.jaxp.datatype.DatatypeFactoryImpl -Djavax.xml.parsers.DocumentBuilderFactory=com.sun.org.apache.xerces.internal.jaxp.DocumentBuilderFactoryImpl -Djavax.xml.parsers.SAXParserFactory=com.sun.org.apache.xerces.internal.jaxp.SAXParserFactoryImpl -Djavax.xml.validation.SchemaFactory:http://www.w3.org/2001/XMLSchema=com.sun.org.apache.xerces.internal.jaxp.validation.XMLSchemaFactory -Dorg.xml.sax.driver=com.sun.org.apache.xerces.internal.parsers.SAXParser -Dorg.w3c.dom.DOMImplementationSourceList=com.sun.org.apache.xerces.internal.dom.DOMXSImplementationSourceImpl -Djavax.net.ssl.sessionCacheSize=10000 -Dscala.reflect.runtime.disable.typetag.cache=true -Dcom.google.cloud.spark.bigquery.repackaged.io.netty.tryReflectionSetAccessible=true -Dlog4j2.formatMsgNoLookups=true -Ddatabricks.serviceName=spark-executor-1'),
#  ('spark.akka.frameSize', '256'),
#  ('spark.hadoop.fs.s3a.fast.upload', 'true'),
#  ('spark.hadoop.fs.wasbs.impl',
#   'shaded.databricks.org.apache.hadoop.fs.azure.NativeAzureFileSystem'),
#  ('spark.sql.streaming.stopTimeout', '15s'),
#  ('spark.hadoop.hive.server2.keystore.password', '[REDACTED]'),
#  ('spark.driver.memory', '4g'),
#  ('spark.databricks.overrideDefaultCommitProtocol',
#   'org.apache.spark.sql.execution.datasources.SQLHadoopMapReduceCommitProtocol'),
#  ('spark.worker.aioaLazyConfig.dbfsReadinessCheckClientClass',
#   'com.databricks.backend.daemon.driver.NephosDbfsReadinessCheckClient'),
#  ('libraryDownload.timeoutSeconds', '180'),
#  ('spark.hadoop.parquet.memory.pool.ratio', '0.5'),
#  ('spark.databricks.passthrough.adls.gen2.tokenProviderClassName',
#   'com.databricks.backend.daemon.data.client.adl.AdlGen2CredentialContextTokenProvider'),
#  ('spark.hadoop.fs.s3a.block.size', '67108864'),
#  ('spark.databricks.tahoe.logStore.gcp.class',
#   'com.databricks.tahoe.store.GCPLogStore'),
#  ('spark.serializer.objectStreamReset', '100'),
#  ('spark.sql.sources.commitProtocolClass',
#   'com.databricks.sql.transaction.directory.DirectoryAtomicCommitProtocol'),
#  ('spark.databricks.passthrough.enabled', 'false'),
#  ('spark.hadoop.fs.abfss.impl',
#   'shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.SecureAzureBlobFileSystem'),
#  ('spark.hadoop.fs.fcfs-s3a.impl',
#   'com.databricks.sql.acl.fs.FixedCredentialsFileSystem'),
#  ('spark.databricks.clusterUsageTags.instanceWorkerEnvId',
#   'workerenv-4285859980626871-2192fbcf-7067-4a0b-a529-f13645141655'),
#  ('spark.app.id', 'app-20221213215517-0000'),
#  ('spark.shuffle.service.enabled', 'true'),
#  ('spark.hadoop.fs.file.impl',
#   'com.databricks.backend.daemon.driver.WorkspaceLocalFileSystem'),
#  ('spark.hadoop.fs.mcfs-s3n.impl',
#   'com.databricks.sql.acl.fs.ManagedCatalogFileSystem'),
#  ('spark.hadoop.fs.fcfs-wasb.impl.disable.cache', 'true'),
#  ('spark.hadoop.fs.cpfs-s3.impl',
#   'com.databricks.sql.acl.fs.CredentialPassthroughFileSystem'),
#  ('spark.hadoop.fs.s3a.multipart.threshold', '104857600'),
#  ('spark.rpc.message.maxSize', '256'),
#  ('spark.hadoop.fs.elfs.impl',
#   'com.databricks.backend.daemon.data.client.unitycatalog.ExternalLocationFileSystem'),
#  ('spark.databricks.clusterUsageTags.executorPodPoolEnabled', 'false'),
#  ('spark.hadoop.fs.fcfs-wasbs.impl',
#   'com.databricks.sql.acl.fs.FixedCredentialsFileSystem'),
#  ('spark.databricks.driverNfs.enabled', 'true'),
#  ('spark.hadoop.parquet.page.metadata.validation.enabled', 'true'),
#  ('spark.databricks.acl.enabled', 'false'),
#  ('spark.databricks.clusterUsageTags.isDbletNode', 'false'),
#  ('spark.databricks.clusterUsageTags.dbsqlChannel', ''),
#  ('spark.databricks.passthrough.glue.executorServiceFactoryClassName',
#   'com.databricks.backend.daemon.driver.credentials.GlueClientExecutorServiceFactory'),
#  ('spark.hadoop.fs.abfs.impl',
#   'shaded.databricks.azurebfs.org.apache.hadoop.fs.azurebfs.AzureBlobFileSystem'),
#  ('spark.databricks.acl.scim.client',
#   'com.databricks.spark.sql.acl.client.DriverToWebappScimClient'),
#  ('spark.hadoop.databricks.s3.amazonS3Client.cache.enabled', 'false'),
#  ('spark.hadoop.fs.adl.impl.disable.cache', 'true'),
#  ('spark.hadoop.parquet.block.size.row.check.max', '10'),
#  ('spark.hadoop.fs.s3a.connection.maximum', '200'),
#  ('spark.databricks.clusterUsageTags.numPerClusterInitScriptsV2', '0'),
#  ('spark.hadoop.fs.s3a.assumed.role.credentials.provider',
#   'com.amazonaws.auth.InstanceProfileCredentialsProvider'),
#  ('spark.hadoop.fs.s3a.fast.upload.active.blocks', '32'),
#  ('spark.shuffle.reduceLocality.enabled', 'false'),
#  ('spark.hadoop.spark.sql.sources.outputCommitterClass',
#   'com.databricks.backend.daemon.data.client.MapReduceDirectOutputCommitter'),
#  ('spark.hadoop.fs.fcfs-abfs.impl',
#   'com.databricks.sql.acl.fs.FixedCredentialsFileSystem'),
#  ('spark.hadoop.fs.fcfs-abfss.impl.disable.cache', 'true'),
#  ('spark.hadoop.hive.server2.thrift.http.cookie.auth.enabled', 'false'),
#  ('spark.hadoop.spark.hadoop.aws.glue.cache.table.size', '1000'),
#  ('spark.sql.parquet.compression.codec', 'snappy'),
#  ('spark.databricks.clusterUsageTags.clusterK8sClusterUUID',
#   '5a8f816e-cc03-4387-b991-52ded81a3d72'),
#  ('spark.databricks.clusterUsageTags.driverNodeType', 'e2-highmem-2'),
#  ('spark.hadoop.databricks.s3.create.deleteUnnecessaryFakeDirectories',
#   'false'),
#  ('spark.databricks.clusterUsageTags.ngrokNpipEnabled', 'true'),
#  ('spark.hadoop.fs.wasb.impl',
#   'shaded.databricks.org.apache.hadoop.fs.azure.NativeAzureFileSystem'),
#  ('spark.hadoop.fs.mcfs-abfss.impl.disable.cache', 'true'),
#  ('spark.hadoop.spark.hadoop.aws.glue.cache.db.size', '1000'),
#  ('spark.databricks.unityCatalog.enabled', 'false'),
#  ('spark.databricks.passthrough.glue.credentialsProviderFactoryClassName',
#   'com.databricks.backend.daemon.driver.credentials.DatabricksCredentialProviderFactory'),
#  ('spark.sparklyr-backend.threads', '1'),
#  ('spark.hadoop.fs.fcfs-wasb.impl',
#   'com.databricks.sql.acl.fs.FixedCredentialsFileSystem'),
#  ('spark.databricks.passthrough.s3a.tokenProviderClassName',
#   'com.databricks.backend.daemon.driver.aws.AwsCredentialContextTokenProvider'),
#  ('spark.databricks.session.share', 'false'),
#  ('spark.hadoop.fs.idbfs.impl', 'com.databricks.io.idbfs.IdbfsFileSystem'),
#  ('spark.driver.extraJavaOptions',
#   '-XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED'),
#  ('spark.databricks.clusterUsageTags.clusterName', 'G15-Cluster'),
#  ('spark.app.startTime', '1670968501230'),
#  ('spark.hadoop.fs.gs.impl.disable.cache', 'true'),
#  ('spark.databricks.clusterUsageTags.region', 'us-west1'),
#  ('spark.delta.sharing.profile.provider.class',
#   'io.delta.sharing.DeltaSharingCredentialsProvider'),
#  ('spark.databricks.managedCatalog.gcs.tokenProviderClassName',
#   'com.databricks.backend.daemon.driver.credentials.ManagedCatalogGCSTokenProvider'),
#  ('spark.worker.aioaLazyConfig.iamReadinessCheckClientClass',
#   'com.databricks.backend.daemon.driver.NephosIamRoleCheckClient'),
#  ('spark.databricks.clusterUsageTags.clusterScalingType', 'autoscaling'),
#  ('spark.databricks.automl.serviceEnabled', 'true'),
#  ('spark.hadoop.parquet.page.size.check.estimate', 'false'),
#  ('spark.hadoop.spark.driverproxy.customHeadersToProperties',
#   'X-Databricks-User-Token:spark.databricks.token,X-Databricks-Api-Url:spark.databricks.api.url,X-Databricks-ADLS-Gen1-Token:spark.databricks.adls.gen1.token,X-Databricks-ADLS-Gen2-Token:spark.databricks.adls.gen2.token,X-Databricks-Synapse-Token:spark.databricks.synapse.token,X-Databricks-AWS-Credentials:spark.databricks.aws.creds,X-Databricks-User-Id:spark.databricks.user.id,X-Databricks-User-Name:spark.databricks.user.name'),
#  ('spark.databricks.passthrough.s3a.threadPoolExecutor.factory.class',
#   'com.databricks.backend.daemon.driver.aws.S3APassthroughThreadPoolExecutorFactory'),
#  ('spark.databricks.metrics.filesystem_io_metrics', 'true'),
#  ('spark.databricks.workerNodeTypeId', 'e2-highmem-2'),
#  ('spark.databricks.cloudfetch.requesterClassName',
#   'com.databricks.spark.sql.cloudfetch.DataDaemonCloudPresignedUrlRequester'),
#  ('spark.databricks.clusterUsageTags.nephosInstantComputePriority', ''),
#  ('spark.databricks.delta.logStore.crossCloud.fatal', 'true'),
#  ('spark.databricks.driverNfs.clusterWidePythonLibsEnabled', 'true'),
#  ('spark.ui.reverseProxyUrl',
#   '/driver-proxy/o/4285859980626871/1213-212447-k68mp9tw/48884/'),
#  ('spark.files.fetchFailure.unRegisterOutputOnHost', 'true'),
#  ('spark.driver.port', '36703'),
#  ('spark.databricks.clusterUsageTags.clusterSizeType', 'K8S_ST_CONTAINER'),
#  ('spark.hadoop.databricks.fs.perfMetrics.enable', 'true'),
#  ('spark.hadoop.fs.gs.outputstream.upload.chunk.size', '16777216'),
#  ('spark.databricks.clusterUsageTags.clusterAvailability', 'ONDEMAND'),
#  ('spark.speculation.quantile', '0.9'),
#  ('spark.databricks.clusterUsageTags.privateLinkEnabled', 'false'),
#  ('spark.shuffle.manager', 'SORT'),
#  ('spark.files.overwrite', 'true'),
#  ('spark.databricks.credential.aws.secretKey.redactor',
#   'com.databricks.spark.util.AWSSecretKeyRedactorProxy'),
#  ('spark.r.numRBackendThreads', '1'),
#  ('spark.hadoop.fs.wasbs.impl.disable.cache', 'true'),
#  ('spark.hadoop.fs.abfss.impl.disable.cache', 'true'),
#  ('spark.hadoop.fs.azure.cache.invalidator.type',
#   'com.databricks.encryption.utils.CacheInvalidatorImpl'),
#  ('spark.sql.hive.metastore.version', '0.13.0'),
#  ('spark.shuffle.service.port', '4048'),
#  ('spark.databricks.clusterUsageTags.instanceWorkerEnvNetworkType', 'default'),
#  ('spark.databricks.acl.client',
#   'com.databricks.spark.sql.acl.client.SparkSqlAclClient'),
#  ('spark.streaming.driver.writeAheadLog.closeFileAfterWrite', 'true'),
#  ('spark.hadoop.hive.warehouse.subdir.inherit.perms', 'false'),
#  ('spark.hadoop.fs.mcfs-abfss.impl',
#   'com.databricks.sql.acl.fs.ManagedCatalogFileSystem'),
#  ('spark.databricks.sparkContextId', '3353939519495889208'),
#  ('spark.hadoop.fs.s3n.impl',
#   'shaded.databricks.org.apache.hadoop.fs.s3a.S3AFileSystem'),
#  ('spark.databricks.enablePublicDbfsFuse', 'false'),
#  ('spark.databricks.clusterUsageTags.enableElasticDisk', 'false'),
#  ('spark.hadoop.fs.fcfs-wasbs.impl.disable.cache', 'true'),
#  ('spark.driver.host', 'driver-proxy'),
#  ('spark.executor.memory', '4g'),
#  ('spark.databricks.passthrough.adls.tokenProviderClassName',
#   'com.databricks.backend.daemon.data.client.adl.AdlCredentialContextTokenProvider'),
#  ('spark.app.name', 'Databricks Shell'),
#  ('spark.driver.allowMultipleContexts', 'false'),
#  ('spark.hadoop.fs.AbstractFileSystem.gs.impl',
#   'shaded.databricks.com.google.cloud.hadoop.fs.gcs.GoogleHadoopFS'),
#  ('spark.databricks.thriftserver.ssl.ciphers.exclude',
#   '^.*_(MD5|SHA1)$,^TLS_RSA_.*$, ^SSL_.*$, ^.*_NULL_.*$, ^.*_anon_.*$'),
#  ('spark.databricks.secret.sparkConf.keys.toRedact', ''),
#  ('spark.repl.class.outputDir',
#   '/local_disk0/tmp/repl/spark-3353939519495889208-e930cd9c-c073-42e8-8e51-ba42cf6cb172'),
#  ('spark.rdd.compress', 'true'),
#  ('spark.hadoop.spark.databricks.io.parquet.verifyChecksumOnWrite.throwsException',
#   'false'),
#  ('spark.databricks.python.defaultPythonRepl', 'ipykernel'),
#  ('spark.databricks.clusterUsageTags.clusterAllTags',
#   '[{"key":"ClusterId","value":"1213-212447-k68mp9tw"},{"key":"ClusterName","value":"G15-Cluster"},{"key":"Creator","value":"trihu038_at_gmail.com"},{"key":"Vendor","value":"Databricks"}]'),
#  ('spark.databricks.eventLog.dir', 'eventlogs'),
#  ('spark.databricks.clusterUsageTags.clusterUnityCatalogMode', 'NONE'),
#  ('spark.databricks.driverNfs.pathSuffix', '.ephemeral_nfs'),
#  ('spark.databricks.clusterUsageTags.clusterCreator', 'Webapp'),
#  ('spark.speculation', 'false'),
#  ('spark.hadoop.hive.server2.session.check.interval', '60000'),
#  ('spark.sql.hive.convertCTAS', 'true'),
#  ('spark.hadoop.fs.s3a.max.total.tasks', '1000'),
#  ('spark.hadoop.spark.sql.parquet.output.committer.class',
#   'org.apache.spark.sql.parquet.DirectParquetOutputCommitter'),
#  ('spark.databricks.clusterUsageTags.autoTerminationMinutes', '10'),
#  ('spark.databricks.tahoe.logStore.aws.class',
#   'com.databricks.tahoe.store.MultiClusterLogStore'),
#  ('spark.hadoop.fs.s3a.fast.upload.default', 'true'),
#  ('spark.hadoop.fs.mlflowdbfs.impl',
#   'com.databricks.mlflowdbfs.MlflowdbfsFileSystem'),
#  ('spark.databricks.eventLog.listenerClassName',
#   'com.databricks.backend.daemon.driver.DBCEventLoggingListener'),
#  ('spark.hadoop.fs.abfs.impl.disable.cache', 'true'),
#  ('spark.speculation.multiplier', '3'),
#  ('spark.storage.blockManagerTimeoutIntervalMs', '300000'),
#  ('spark.databricks.driverNodeTypeId', 'e2-highmem-2'),
#  ('spark.sparkr.use.daemon', 'false'),
#  ('spark.scheduler.listenerbus.eventqueue.capacity', '20000'),
#  ('spark.databricks.clusterUsageTags.sparkVersion', '11.0.x-scala2.12'),
#  ('spark.hadoop.parquet.page.write-checksum.enabled', 'true'),
#  ('spark.databricks.clusterUsageTags.clusterLocalSsdCounts', '0'),
#  ('spark.hadoop.fs.s3a.threads.max', '136'),
#  ('spark.hadoop.databricks.s3commit.client.sslTrustAll', 'false'),
#  ('spark.r.backendConnectionTimeout', '604800'),
#  ('spark.hadoop.hive.server2.idle.session.timeout', '900000'),
#  ('spark.databricks.redactor',
#   'com.databricks.spark.util.DatabricksSparkLogRedactorProxy'),
#  ('spark.hadoop.fs.s3a.impl',
#   'shaded.databricks.org.apache.hadoop.fs.s3a.S3AFileSystem'),
#  ('spark.executor.extraClassPath',
#   '/databricks/spark/dbconf/log4j/executor:/databricks/spark/dbconf/jets3t/:/databricks/spark/dbconf/hadoop:/databricks/hive/conf:/databricks/jars/*'),
#  ('spark.hadoop.fs.fcfs-abfs.impl.disable.cache', 'true'),
#  ('spark.hadoop.parquet.page.verify-checksum.enabled', 'true'),
#  ('spark.logConf', 'true'),
#  ('spark.databricks.clusterUsageTags.gcpProjectId', 'g15-task3-project'),
#  ('spark.hadoop.hive.server2.enable.doAs', 'false'),
#  ('eventLog.rolloverIntervalSeconds', '3600'),
#  ('spark.hadoop.parquet.filter.columnindex.enabled', 'false'),
#  ('spark.shuffle.memoryFraction', '0.2'),
#  ('spark.hadoop.fs.dbfsartifacts.impl',
#   'com.databricks.backend.daemon.data.client.DBFSV1'),
#  ('spark.hadoop.fs.cpfs-s3a.impl',
#   'com.databricks.sql.acl.fs.CredentialPassthroughFileSystem'),
#  ('spark.hadoop.fs.s3a.connection.timeout', '50000'),
#  ('spark.databricks.secret.envVar.keys.toRedact', ''),
#  ('spark.files.useFetchCache', 'false')]

# %%
sc._conf.get('spark.executor.memory'), sc._conf.get('spark.driver.memory')
# Out:
# Out[3]: ('4g', '4g')

# %%
file_path = 'gs://g15-bucket/nyt_apidata'

# %%
df = spark.read.format("com.databricks.spark.csv")\
    .option('delimiter',',').option('header',True)\
    .option("timestampFormat", "yyyy-MM-dd'T'HH:mm:ssx")\
    .option("quote", '\"').option("escape", "\"").option("multiline", True).option("inferSchema", True).csv(file_path)

# %%
rdd = df.rdd.map(list)
rdd.count()
# Out:
# Out[7]: 2894493

# %% [markdown]
# ## Data Preparation

# %%
dw_mapping={0: 'Monday', 1: 'Tuesday', 2: 'Wednesday',3: 'Thursday',4: 'Friday',5: 'Saturday', 6: 'Sunday'}

# %%
#x[9] = 'section_name', x[5] = 'keywords', x[6] = 'pub_date'
rdd2 = rdd.map(lambda x:[x[9], x[5], x[6], str(x[6]).replace(' ','-').replace('T', '-').replace(':', '-').replace('+', '-').split('-')])\
                .filter(lambda x: len(x[3])==7 and len(x[2])==24 and len(x[3][0])==4)\
                .map(lambda x: [dt.fromisoformat(x[2].split('+')[0]).date(), x[0], eval(x[1])])\
                .map(lambda x: [x[0], x[0].year, x[0].month, x[0].day, dw_mapping[x[0].weekday()], x[1], 
                                None if len(x[2])==0 else x[2][0]['name'].lower(), None if len(x[2])==0 else x[2][0]['value'].lower()])
    
rdd2.cache()
# Out:
# Out[10]: PythonRDD[10] at RDD at PythonRDD.scala:58

# %%
#rdd2.count(), rdd2.take(3)

# %%
#getting a list of different types of keywords
#locations list
rdd_l = rdd2.filter(lambda x: x[6] == 'glocations').map(lambda x: (x[7], 1)).reduceByKey(lambda x, y: x+y)\
    .filter(lambda x: x[1] >= 200).map(lambda x : [x[0], x[1]]).sortBy(lambda x: x[1], ascending = False)
loc_list = rdd_l.keys().filter(lambda x: x !='new york city').collect()

#subjects list
rdd_s = rdd2.filter(lambda x: x[6] == 'subject').map(lambda x: (x[7], 1)).reduceByKey(lambda x, y: x+y)\
    .filter(lambda x: x[1] >= 100).map(lambda x : [x[0], x[1]]).sortBy(lambda x: x[1], ascending = False)
sub_list = rdd_s.keys().filter(lambda x: x!='company earnings' and x!='company reports' and x!='no index terms').collect()

#organizations list
rdd_o = rdd2.filter(lambda x: x[6] == 'organizations').map(lambda x: (x[7], 1)).reduceByKey(lambda x, y: x+y)\
    .filter(lambda x: x[1] >= 100).map(lambda x : [x[0], x[1]]).sortBy(lambda x: x[1], ascending = False)
org_list = rdd_o.keys().collect()

# %%
#type of keywords in news articles
rdd_t = rdd2.map(lambda x: (x[6], 1)).reduceByKey(lambda x, y: x+y)
rdd_t.collect()
# Out:
# Out[14]: [(None, 503064),
#  ('glocations', 589551),
#  ('creative_works', 4393),
#  ('organizations', 427074),
#  ('subject', 864790),
#  ('persons', 505621)]

# %% [markdown]
# ## Creating Plotly Graphs

# %% [markdown]
# ### Display Yearly Trend (Deepak Singh)
#
# - Create a stacked bar chart showing yearly counts of news published per weekday

# %%
#Weekly Trends
rdd6 = rdd2.map(lambda x: ((x[1], x[4]), 1)).reduceByKey(lambda x, y: x+y)\
    .map(lambda x : [x[0][0], x[0][1], x[1]]).filter(lambda x: x[0] >1990)
rdd6.count(), rdd6.take(5)
# Out:
# Out[19]: (217,
#  [[2003, 'Sunday', 29264],
#   [1995, 'Tuesday', 10221],
#   [1993, 'Thursday', 10505],
#   [2013, 'Tuesday', 13259],
#   [2015, 'Monday', 11688]])

# %%
# Weekly News Publications on all Topics
org_count_df = pd.DataFrame(rdd6.collect(), columns=['year', 'weekday', 'count'])
fig = px.bar(org_count_df, 
                 x="year", 
                 y="count",
                 color="weekday",
                 height=800,
                 width = 1200,
                 title = 'Yearly Trend of News Articles per weekday'
                )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="58b59cc5-19eb-4cd9-ad9b-1abcd04e05d7" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58b59cc5-19eb-4cd9-ad9b-1abcd04e05d7")) {                    Plotly.newPlot(                        "58b59cc5-19eb-4cd9-ad9b-1abcd04e05d7",                        [{"alignmentgroup":"True","hovertemplate":"weekday=Sunday<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Sunday","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Sunday","offsetgroup":"Sunday","orientation":"v","showlegend":true,"textposition":"auto","x":[2003,1992,2006,2001,1998,2011,2018,1991,1995,2020,2000,1996,2005,1993,2004,2019,2002,2013,2009,2007,2015,1997,2017,1999,2008,1994,2010,2021,2012,2014,2016],"xaxis":"x","y":[29264,24777,39664,30222,27827,5530,4630,25115,26067,3688,29782,24643,29578,24535,28295,4391,29885,5889,6935,20601,5505,26734,4707,28390,14828,24623,5619,3508,6672,5573,4976],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"weekday=Tuesday<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Tuesday","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Tuesday","offsetgroup":"Tuesday","orientation":"v","showlegend":true,"textposition":"auto","x":[1995,2013,2010,2020,1993,2011,1996,2001,1998,2005,1992,2003,1994,1999,2015,2004,2000,2017,2019,2012,2021,2009,2002,2016,2014,1991,2006,2008,1997,2007,2018],"xaxis":"x","y":[10221,13259,17126,10213,10073,14947,9574,14500,11629,16227,10321,14556,9723,12332,12366,14359,12879,9331,8703,15170,9377,24249,14798,10315,12587,10426,22158,18079,11336,14111,10948],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"weekday=Thursday<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Thursday","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Thursday","offsetgroup":"Thursday","orientation":"v","showlegend":true,"textposition":"auto","x":[1993,1996,2021,1994,2014,2007,2015,1999,2010,1998,2004,2012,2006,2017,1995,2016,2020,2009,2019,1992,2003,2005,2001,2011,2018,1997,2008,1991,2000,2002,2013],"xaxis":"x","y":[10505,10010,9954,9906,15393,15417,14581,13145,19790,12948,15496,17859,22955,11196,11710,12787,10330,26466,10211,12309,14959,17593,15619,17985,10877,11278,19178,11509,14208,15318,15655],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"weekday=Monday<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Monday","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Monday","offsetgroup":"Monday","orientation":"v","showlegend":true,"textposition":"auto","x":[2015,2000,1997,2016,2002,2009,1995,1998,2018,1996,2011,1993,2012,2005,1991,2014,2007,1992,2008,1994,2021,2010,2003,2004,2001,2017,1999,2006,2019,2020,2013],"xaxis":"x","y":[11688,8955,8428,10152,9638,22639,7542,8610,7827,7415,15028,8177,14787,11960,8447,12835,12310,9020,16023,7069,7192,17026,9596,9719,10064,8348,8747,17837,7277,7413,12876],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"weekday=Saturday<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Saturday","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Saturday","offsetgroup":"Saturday","orientation":"v","showlegend":true,"textposition":"auto","x":[1998,2014,2021,1995,1992,2019,2005,2009,2012,2016,2004,1996,2007,1994,2008,2010,2002,2000,2013,2011,1999,1993,1991,1997,2020,2003,2015,2001,2018,2017,2006],"xaxis":"x","y":[8596,7763,3690,8335,8104,4151,12143,13910,10607,5969,10159,7687,8556,7852,11509,11577,10196,9919,8886,11525,8640,7986,8654,8364,4062,9831,6692,10507,4331,4886,13982],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"weekday=Wednesday<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Wednesday","marker":{"color":"#19d3f3","pattern":{"shape" ...

# %% [markdown]
# <div style="border-radius:10px; border : #682F2F solid; background-color:#e1f6e1; font-size:100%; padding-left:10px; text-align:left">
# <h3> The above stacked bar chart indicates changing patterns in published news articles </h3>
# - Before 2006, most of the news was published on Sundays <br>
# - After 2006, there has been a declining trend in overall number of articles published <br>
# - Barring Saturday, Monday and Sunday, all other days are seeing an almost equal number of news articles being published <br>
# - Years 2006 and 2009 saw a sudden spike in number of news articles <br>

# %% [markdown]
# ### Top Newsworthy Locations (Deepak Singh)
#
# - Create a scatter plot showing yearly counts of news published per location

# %%
# locations
rdd3 = rdd2.filter(lambda x: x[6] == 'glocations').map(lambda x: ((x[7], x[0].year), 1)).reduceByKey(lambda x, y: x+y)\
    .filter(lambda x: x[1] >= 200).map(lambda x : [x[0][0], x[0][1], x[1]])
rdd3.count(), rdd3.take(5)
# Out:
# Out[15]: (409,
#  [['new orleans (la)', 2005, 441],
#   ['israel', 2002, 1037],
#   ['great britain', 2001, 551],
#   ['europe', 2001, 648],
#   ['israel', 2003, 744]])

# %%
# Top Newsworthy Locations
loc_count_df = pd.DataFrame(rdd3.collect(), columns=['locations', 'year', 'count'])
fig = px.scatter(loc_count_df[loc_count_df['locations'].isin(loc_list)], 
                 x="year", 
                 y="count",
                 color="locations",
                 height=600, 
                 width = 1200,
                 title = 'Yearly Trend of News Articles from different Locations'
                )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="3a8848c1-72ca-4173-9678-9a1c204b4a65" class="plotly-graph-div" style="height:600px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a8848c1-72ca-4173-9678-9a1c204b4a65")) {                    Plotly.newPlot(                        "3a8848c1-72ca-4173-9678-9a1c204b4a65",                        [{"hovertemplate":"locations=new orleans (la)<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"new orleans (la)","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"new orleans (la)","orientation":"v","showlegend":true,"x":[2005,2006],"xaxis":"x","y":[441,568],"yaxis":"y","type":"scatter"},{"hovertemplate":"locations=israel<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"israel","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"israel","orientation":"v","showlegend":true,"x":[2002,2003,2000,2001,2006,1999,1998,2004,1996,2005,1997],"xaxis":"x","y":[1037,744,553,752,460,333,437,572,289,418,490],"yaxis":"y","type":"scatter"},{"hovertemplate":"locations=great britain<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"great britain","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"great britain","orientation":"v","showlegend":true,"x":[2001,2000,1999,2003,1998,1992,1993,2002,1995,2005,2004,1994,1997,1996,1991,2006],"xaxis":"x","y":[551,528,456,811,459,374,363,724,397,542,616,359,564,476,447,656],"yaxis":"y","type":"scatter"},{"hovertemplate":"locations=europe<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"europe","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"europe","orientation":"v","showlegend":true,"x":[2001,1999,1998,1991,1997,2000,2006,1996,2005,1995,1994,1993,2004,2002,2003,1992],"xaxis":"x","y":[648,405,368,311,360,509,426,242,354,214,252,293,602,584,594,337],"yaxis":"y","type":"scatter"},{"hovertemplate":"locations=texas<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"texas","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"texas","orientation":"v","showlegend":true,"x":[2003,2000,2014,2004],"xaxis":"x","y":[219,237,222,211],"yaxis":"y","type":"scatter"},{"hovertemplate":"locations=united states<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"united states","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"united states","orientation":"v","showlegend":true,"x":[1992,1991,2000,1999,1998,2006,1997,2005,1996,1995,1994,2004,2002,2003,1993,2001],"xaxis":"x","y":[2314,2804,1196,1361,1597,1240,2138,817,1916,2518,1780,1221,1630,1562,2660,1674],"yaxis":"y","type":"scatter"},{"hovertemplate":"locations=new york state<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"new york state","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"new york state","orientation":"v","showlegend":true,"x":[1992,1993,2001,2000,1994,2009,2008,2002,2010,1995,1997,1996,2003,2005,2004,1998,2006,1991,1999,2007],"xaxis":"x","y":[1501,1114,1050,1931,1551,261,239,1630,217,1233,1275,1244,1443,969,1560,1490,2241,1055,1457,283],"yaxis":"y","type":"scatter"},{"hovertemplate":"locations=westchester county (ny)<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"westchester county (ny)","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"westchester county (ny)","orientation":"v","showlegend":true,"x":[1992,1993,1995,2006,2001,2000,1994,2003,1997,1996,1999,1991,2002,2005,2004,1998],"xaxis":"x","y":[308,307,260,273,242,375,278,275,289,221,267,284,291,264,307,291],"yaxis":"y","type":"scatter"},{"hovertemplate":"locations=somalia<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"somalia","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"somalia","orientation":" ...

# %% [markdown]
# <div style="border-radius:10px; border : #682F2F solid; background-color:#e1f6e1; font-size:100%; padding-left:10px; text-align:left">
# <h3> The above scatter plot highlights the following key points </h3>
# - Prior to 2006, news articles were being published on a diverse range of locations across the world <br>
# - This has reduced drastically post 2006, and only a few locations see coverage of more than 200 news articles per year <br>
# - The news locations of most interest in the past few years have been: China, California, Iran, Ukraine, Russia <br>

# %% [markdown]
# ### Yearly Trend of News Articles Topics (Tianrui)
#
# - Create a scatter plot showing yearly counts of news published per topic of interest

# %%
#Topics or Subjects
rdd4 = rdd2.filter(lambda x: x[6] == 'subject').map(lambda x: ((x[7], x[0].year), 1)).reduceByKey(lambda x, y: x+y)\
    .filter(lambda x: x[1] >= 300).map(lambda x : [x[0][0], x[0][1], x[1]])
rdd4.count(), rdd4.take(5)
# Out:
# Out[23]: (421,
#  [['mergers, acquisitions and divestitures', 2009, 415],
#   ['united states economy', 2009, 786],
#   ['travel and vacations', 2008, 1156],
#   ['mergers, acquisitions and divestitures', 2008, 524],
#   ['housing', 2008, 429]])

# %%
# Top Newsworthy Topics
sub_count_df = pd.DataFrame(rdd4.collect(), columns=['topics', 'year', 'count'])
fig = px.scatter(sub_count_df[sub_count_df['topics'].isin(sub_list)], 
                 x="year", 
                 y="count",
                 color="topics",
                 height=500,
                 width = 1200,
                 title = 'Yearly Trend of News Articles focusing on Various Topics'
                )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="d5013ece-4a14-4546-b689-b68a7d896194" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5013ece-4a14-4546-b689-b68a7d896194")) {                    Plotly.newPlot(                        "d5013ece-4a14-4546-b689-b68a7d896194",                        [{"hovertemplate":"topics=mergers, acquisitions and divestitures<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"mergers, acquisitions and divestitures","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"mergers, acquisitions and divestitures","orientation":"v","showlegend":true,"x":[2009,2008,2011,2010,2012,2013,2015,2007,2014,2006],"xaxis":"x","y":[415,524,657,558,562,431,321,749,533,392],"yaxis":"y","type":"scatter"},{"hovertemplate":"topics=united states economy<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"united states economy","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"united states economy","orientation":"v","showlegend":true,"x":[2009,2020,2010,2011,2008,2021],"xaxis":"x","y":[786,380,538,443,829,305],"yaxis":"y","type":"scatter"},{"hovertemplate":"topics=travel and vacations<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"travel and vacations","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"travel and vacations","orientation":"v","showlegend":true,"x":[2008,2016,2009,2006,2007,2017,2014,2015,2012,2013,2010,2011,2018,2019],"xaxis":"x","y":[1156,514,864,1128,1658,426,400,709,800,413,832,1368,457,336],"yaxis":"y","type":"scatter"},{"hovertemplate":"topics=housing<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"housing","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"housing","orientation":"v","showlegend":true,"x":[2008,2007],"xaxis":"x","y":[429,407],"yaxis":"y","type":"scatter"},{"hovertemplate":"topics=art<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"art","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"art","orientation":"v","showlegend":true,"x":[2012,2013,2014,2019,2020,2021,2007,2015,2009,2008,2010,2016,2017,2011,2018],"xaxis":"x","y":[1061,1457,1257,779,599,557,319,1419,467,453,675,1062,904,1133,845],"yaxis":"y","type":"scatter"},{"hovertemplate":"topics=labor and jobs<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"labor and jobs","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"labor and jobs","orientation":"v","showlegend":true,"x":[2012,2010,2011],"xaxis":"x","y":[320,312,379],"yaxis":"y","type":"scatter"},{"hovertemplate":"topics=banks and banking<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"banks and banking","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"banks and banking","orientation":"v","showlegend":true,"x":[2010],"xaxis":"x","y":[428],"yaxis":"y","type":"scatter"},{"hovertemplate":"topics=soccer<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"soccer","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"soccer","orientation":"v","showlegend":true,"x":[2011,2012,2013,2015],"xaxis":"x","y":[593,628,400,374],"yaxis":"y","type":"scatter"},{"hovertemplate":"topics=television<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"television","marker":{"color":"#FF97FF","symbol":"circle"},"mode":"markers","name":"television","orientation":"v","showlegend":true,"x":[2011,2016,2017,2019,2013,2005,2015,2018,2020,2021,2014],"xaxis":"x","y":[446,1201,1170,984,640,427,1283,1057,823,789,678],"yaxis":"y","type":"scatter"},{"hovertemplate":"topics=tennis<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"tennis","marker":{"color":"#FECB52","symbol":"circle"},"mode":"markers","name":"tennis","orient ...

# %% [markdown]
# <div style="border-radius:10px; border : #682F2F solid; background-color:#e1f6e1; font-size:100%; padding-left:10px; text-align:left">
#     <h3> The above scatter plot highlights the following key points </h3>
# - Prior to 2006, there were only a few topics being published digitally (it could be due to internet/digital propensity) <br>
# - Coronavirus and Presidential elections of 2020 are the clear highlights of the past couple of years <br>

# %% [markdown]
# ### Trend of News Sections (Vichitra)

# %%
rdd_section = rdd.map(lambda x: (x[-4], 1)).reduceByKey(lambda x, y: x+y).sortBy(lambda x: x[1], ascending=False).collect()

# %%
section_count_df = pd.DataFrame(rdd_section[:20], columns=['section', 'count'])
fig = px.bar(section_count_df, 
                 x="section", 
                 y="count",
                 color="section",
                 height=800,
                 width = 1200,
                 title = 'Most Popular News Sections in NYT'
                )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="eb123a8c-0518-421e-9bef-5d9a1bacf6a1" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("eb123a8c-0518-421e-9bef-5d9a1bacf6a1")) {                    Plotly.newPlot(                        "eb123a8c-0518-421e-9bef-5d9a1bacf6a1",                        [{"alignmentgroup":"True","hovertemplate":"section=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Business Day","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Business Day","offsetgroup":"Business Day","orientation":"v","showlegend":true,"textposition":"auto","x":["Business Day"],"xaxis":"x","y":[420753],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"section=%{x}<br>count=%{y}<extra></extra>","legendgroup":"New York","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"New York","offsetgroup":"New York","orientation":"v","showlegend":true,"textposition":"auto","x":["New York"],"xaxis":"x","y":[386638],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"section=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Sports","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Sports","offsetgroup":"Sports","orientation":"v","showlegend":true,"textposition":"auto","x":["Sports"],"xaxis":"x","y":[252204],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"section=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Opinion","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Opinion","offsetgroup":"Opinion","orientation":"v","showlegend":true,"textposition":"auto","x":["Opinion"],"xaxis":"x","y":[250315],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"section=%{x}<br>count=%{y}<extra></extra>","legendgroup":"U.S.","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"U.S.","offsetgroup":"U.S.","orientation":"v","showlegend":true,"textposition":"auto","x":["U.S."],"xaxis":"x","y":[245323],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"section=%{x}<br>count=%{y}<extra></extra>","legendgroup":"World","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"World","offsetgroup":"World","orientation":"v","showlegend":true,"textposition":"auto","x":["World"],"xaxis":"x","y":[223436],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"section=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Arts","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Arts","offsetgroup":"Arts","orientation":"v","showlegend":true,"textposition":"auto","x":["Arts"],"xaxis":"x","y":[199442],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"section=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Archives","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"Archives","offsetgroup":"Archives","orientation":"v","showlegend":true,"textposition":"auto","x":["Archives"],"xaxis":"x","y":[140031],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"section=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Books","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"Books","offsetgroup":"Books","orientation":"v","showlegend":true,"textposition":"auto","x":["Books"],"xaxis":"x","y":[74420],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"section=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Style","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"Style","offsetgroup":"Style","orientation":"v","showlegend":true,"textposition":"auto","x":["Style"],"xaxis":"x","y":[68736],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"section=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Technology","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Technology","offsetgroup":"Technolo ...

# %% [markdown]
# <div style="border-radius:10px; border : #682F2F solid; background-color:#e1f6e1; font-size:100%; padding-left:10px; text-align:left">
# <h3> The above bar plot indicates the most popular new sections of NYT </h3>
# - Based on Business Day articles, NYT seems to be the best publisher for business enthusiasts <br>
# - Technology, Science and health gets quite less coverage from NYT <br>
# - Books getting more coverage than technology, science and health and movie aligns with NYT Best Sellers list  <br>

# %% [markdown]
# ###Trend for Diseases Publication (Vichitra)

# %%
def term_counts(rdd, term_list, section='Health'):
    final_df = pd.DataFrame()
    
    for term in term_list:
        temp_rdd = rdd.filter(lambda x: x[0] is not None and x[-4] == section)\
                .filter(lambda x: term in x[0].lower())\
                .map(lambda x: (x[6][:4], 1)).reduceByKey(lambda x, y: x+y)\
                .sortBy(lambda x: x[0], ascending=True)\
                .map(lambda x: (x[0], x[1], term)).collect()
        
        temp_df = pd.DataFrame(temp_rdd, columns = ['year', 'count', 'term'])
        temp_rdd = None
        final_df = pd.concat([final_df, temp_df])
    return final_df

# %%
dff = term_counts(rdd, ['cancer', 'coronavirus', 'vaccine', 'depression', 'heart', 'flu'], section='Health')

# %%
fig = px.line(dff, x="year", y='count', color = 'term', title='Trend for diseases publication')
#fig.update_traces(textposition="bottom right")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="3e69ca81-1765-4975-8854-a68dbdc7e4bf" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e69ca81-1765-4975-8854-a68dbdc7e4bf")) {                    Plotly.newPlot(                        "3e69ca81-1765-4975-8854-a68dbdc7e4bf",                        [{"hovertemplate":"term=cancer<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"cancer","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"cancer","orientation":"v","showlegend":true,"x":["1991","1992","1993","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[19,18,22,6,9,38,40,44,49,40,47,63,110,70,118,169,126,129,114,109,84,55,54,17,29,19,7,16],"yaxis":"y","type":"scatter"},{"hovertemplate":"term=coronavirus<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"coronavirus","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"coronavirus","orientation":"v","showlegend":true,"x":["1991","2013","2020","2021"],"xaxis":"x","y":[1,3,162,83],"yaxis":"y","type":"scatter"},{"hovertemplate":"term=vaccine<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"vaccine","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"vaccine","orientation":"v","showlegend":true,"x":["1991","1992","1993","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[3,2,1,8,11,5,8,15,10,24,31,18,22,43,18,26,21,26,16,21,15,11,17,19,98,134],"yaxis":"y","type":"scatter"},{"hovertemplate":"term=depression<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"depression","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"depression","orientation":"v","showlegend":true,"x":["1991","1992","1993","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[2,3,3,1,2,11,11,13,15,9,15,18,17,11,13,15,22,18,11,16,9,16,9,1,3,4,3,4],"yaxis":"y","type":"scatter"},{"hovertemplate":"term=heart<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"heart","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"heart","orientation":"v","showlegend":true,"x":["1991","1992","1993","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[16,13,14,1,7,33,33,59,43,38,44,70,82,63,48,63,55,62,70,52,51,43,29,7,13,7,6,8],"yaxis":"y","type":"scatter"},{"hovertemplate":"term=flu<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"flu","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"flu","orientation":"v","showlegend":true,"x":["1991","1992","1993","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"],"xaxis":"x","y":[8,7,4,2,14,10,10,7,26,34,61,95,16,20,161,30,25,20,44,23,22,14,7,15,10,16,9],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"ove ...

# %% [markdown]
# <div style="border-radius:10px; border : #682F2F solid; background-color:#e1f6e1; font-size:100%; padding-left:10px; text-align:left">
#  - From the above plot, We can see how other diseases were underreported once COVID hit in 2020 <br>

# %% [markdown]
# ### Yearly Trend for Average Word Count (Vichitra)

# %%
rdd_section_avg = rdd.map(lambda x: (x[6], x[8], x[-1]))\
                     .filter(lambda x: (x[2]>0  and x[1] is not None and x[1] != 'None'))\
                     .map(lambda x: ((int(x[0][:4]), x[1]), x[2])).groupByKey().mapValues(lambda x: sum(x) / len(x))

# %%
desk_words_avg = rdd_section_avg.collect()
ls = [(item[0][0], item[0][1], item[1]) for item in desk_words_avg]
df = pd.DataFrame(ls, columns= ['year', 'desk', 'avg word count'])
df = df[df['desk'].isin(['Classified', 'Business/Financial Desk', 
                         'Metropolitan Desk', 'Editorial Desk', 'Sports Desk',
                          'Foreign Desk', 'National Desk'])]
df = df.sort_values('year')

# %%
fig = px.line(df, x="year", y='avg word count', color = 'desk', title='Trend for avg word from different news desk over the years')
#fig.update_traces(textposition="bottom right")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="73fe90c1-61e3-4f5f-ab12-5ff93064436d" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73fe90c1-61e3-4f5f-ab12-5ff93064436d")) {                    Plotly.newPlot(                        "73fe90c1-61e3-4f5f-ab12-5ff93064436d",                        [{"hovertemplate":"desk=Editorial Desk<br>year=%{x}<br>avg word count=%{y}<extra></extra>","legendgroup":"Editorial Desk","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Editorial Desk","orientation":"v","showlegend":true,"x":[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[419.0172708618331,417.57345383661175,430.6999817618092,432.5516628134448,396.85572632622706,346.2731488406881,309.94698729334607,280.7611381505054,282.2680661577608,283.3587176887988,288.555067185734,295.3467813329961,289.45345382520424,332.39761113163405,347.4362073261899,397.82450691101104],"yaxis":"y","type":"scatter"},{"hovertemplate":"desk=Metropolitan Desk<br>year=%{x}<br>avg word count=%{y}<extra></extra>","legendgroup":"Metropolitan Desk","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Metropolitan Desk","orientation":"v","showlegend":true,"x":[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[539.928187486562,595.9893533123028,618.8207978391855,590.5702516645977,481.642901981885,483.6634092454113,478.0955329153605,540.4746700723712,561.7433327367103,577.869591818897,542.6612709832134,504.5739003383574,489.6462282549341,567.9936117936118,542.9081020555067,481.2367762389454],"yaxis":"y","type":"scatter"},{"hovertemplate":"desk=Foreign Desk<br>year=%{x}<br>avg word count=%{y}<extra></extra>","legendgroup":"Foreign Desk","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Foreign Desk","orientation":"v","showlegend":true,"x":[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[706.2521489971347,796.8832323232323,836.9056724028044,827.9712245781047,779.6526905829596,700.2698347107438,854.1312101910828,853.9379792512404,868.2294708894367,875.7339289605578,700.8567700337734,666.2821869488536,700.8449742268041,769.9284942084942,753.6351796642084,748.1620232172471],"yaxis":"y","type":"scatter"},{"hovertemplate":"desk=National Desk<br>year=%{x}<br>avg word count=%{y}<extra></extra>","legendgroup":"National Desk","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"National Desk","orientation":"v","showlegend":true,"x":[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[763.2472854640981,870.6823236514523,896.2857142857143,931.0356782906672,840.7756154357951,790.3571916404862,862.9686360320934,900.1910112359551,893.9366143240138,875.4232091690544,741.8447877562807,703.2299396031061,746.1855498333838,869.2874344808047,912.8113403849488,825.5931524312512],"yaxis":"y","type":"scatter"},{"hovertemplate":"desk=Sports Desk<br>year=%{x}<br>avg word count=%{y}<extra></extra>","legendgroup":"Sports Desk","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Sports Desk","orientation":"v","showlegend":true,"x":[1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006],"xaxis":"x","y":[563.6142794949935,597.9278184165232,603.5826762784411,633.4778903731,606.5779342723005,573.0909289856659,659.9927784112505,681.7406947890819,695.1758787570046,739.8667958343425,705.7535385014933,728.6273428886439,688.1112705452648,789.8092312089168,807.0608828006089,744.2718834785093],"yaxis":"y","type":"scatter"},{"hovertemplate":"d ...

# %% [markdown]
# ### Yearly Trend of News Articles Organizations(Aydin)
#
# - Create a scatter plot showing organization getting most news coverage in past 30 years

# %%
#Organizations
rdd5 = rdd2.filter(lambda x: x[6] == 'organizations').map(lambda x: ((x[7], x[0].year), 1)).reduceByKey(lambda x, y: x+y)\
    .filter(lambda x: x[1] >= 80).map(lambda x : [x[0][0], x[0][1], x[1]])
rdd5.count(), rdd5.take(5)
# Out:
# Out[25]: (461,
#  [['new york jets', 2002, 198],
#   ['supreme court', 2004, 140],
#   ['united nations', 2001, 103],
#   ['food and drug administration', 2003, 125],
#   ['new york times neediest cases fund', 2009, 98]])

# %%
# Top Newsworthy Organizations
org_count_df = pd.DataFrame(rdd5.collect(), columns=['organization', 'year', 'count'])
fig = px.scatter(org_count_df[org_count_df['organization'].isin(org_list)], 
                 x="year", 
                 y="count",
                 color="organization",
                 height=500,
                 width = 1200,
                 title = 'Yearly Trend of News Articles focusing on Various Organizations'
                )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.9.0.min.js"></script>                <div id="f6daa2cc-f1f7-4fec-ae6e-2d5934f06c43" class="plotly-graph-div" style="height:500px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6daa2cc-f1f7-4fec-ae6e-2d5934f06c43")) {                    Plotly.newPlot(                        "f6daa2cc-f1f7-4fec-ae6e-2d5934f06c43",                        [{"hovertemplate":"organization=new york jets<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"new york jets","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"new york jets","orientation":"v","showlegend":true,"x":[2002,1995,1997,1996,2003,2005,2004,1998,2006,1991,1999,1992,1993,2001,2000,1994],"xaxis":"x","y":[198,154,187,125,181,164,131,185,141,131,195,173,208,194,237,175],"yaxis":"y","type":"scatter"},{"hovertemplate":"organization=supreme court<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"supreme court","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"supreme court","orientation":"v","showlegend":true,"x":[2004,1991,1993,1999,1998,2005,2013,2003,2000,1997,1995,1994,2001,2006],"xaxis":"x","y":[140,378,150,86,104,425,86,102,97,103,93,131,85,171],"yaxis":"y","type":"scatter"},{"hovertemplate":"organization=united nations<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"united nations","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"united nations","orientation":"v","showlegend":true,"x":[2001,2000,1996,2005,1995,2006],"xaxis":"x","y":[103,109,104,158,114,108],"yaxis":"y","type":"scatter"},{"hovertemplate":"organization=food and drug administration<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"food and drug administration","marker":{"color":"#ab63fa","symbol":"circle"},"mode":"markers","name":"food and drug administration","orientation":"v","showlegend":true,"x":[2003,2005,2004,2006,1996,2000,1991,2002],"xaxis":"x","y":[125,135,166,120,101,85,106,132],"yaxis":"y","type":"scatter"},{"hovertemplate":"organization=new york times neediest cases fund<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"new york times neediest cases fund","marker":{"color":"#FFA15A","symbol":"circle"},"mode":"markers","name":"new york times neediest cases fund","orientation":"v","showlegend":true,"x":[2009,2007,2012,2010,2011,2008],"xaxis":"x","y":[98,95,97,96,89,101],"yaxis":"y","type":"scatter"},{"hovertemplate":"organization=new york times<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"new york times","marker":{"color":"#19d3f3","symbol":"circle"},"mode":"markers","name":"new york times","orientation":"v","showlegend":true,"x":[1992,1993,2018,1995,2006,2001,2000,2003,1997,1996,1999,2016,2017,2005,2004,1998],"xaxis":"x","y":[89,127,148,116,125,109,83,127,86,102,111,88,201,122,156,85],"yaxis":"y","type":"scatter"},{"hovertemplate":"organization=new york giants<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"new york giants","marker":{"color":"#FF6692","symbol":"circle"},"mode":"markers","name":"new york giants","orientation":"v","showlegend":true,"x":[1992,1999,1998,2000,2007,2006,1997,2008,2005,1996,2004,1995,1994,2012,2002,2003,1993,2010,2011,2001,2009,1991],"xaxis":"x","y":[322,264,298,296,149,439,321,207,220,268,253,229,330,126,330,316,350,97,92,465,90,414],"yaxis":"y","type":"scatter"},{"hovertemplate":"organization=new york city ballet<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"new york city ballet","marker":{"color":"#B6E880","symbol":"circle"},"mode":"markers","name":"new york city ballet","orientation":"v","showlegend":true,"x":[1999,2005,1992,1993],"xaxis":"x","y":[81,83,80,81],"yaxis":"y","type":"scatter"},{"hovertemplate":"organization=boston red sox<br>year=%{x}<br>count=%{y}<extra></extra>","legendgroup":"boston red sox","marker":{"color":"#FF97F ...

# %% [markdown]
# <div style="border-radius:10px; border : #682F2F solid; background-color:#e1f6e1; font-size:100%; padding-left:10px; text-align:left">
#     <h3> The above scatter plot indicates the following key points </h3>
# - New York Yankees is the organization about which maximum number of articles have been published <br>
# - There has been a decline in the total number of articles per organization per year after 2006 <br>
# - Very few organization in the recent years have had news articles count of more than 100 <br>

# %%
rdd2.unpersist()
# Out:
# Out[34]: PythonRDD[10] at RDD at PythonRDD.scala:58
